# %% [markdown]
# ![CRISP_DM](crisp_dm2.png)

# %% [markdown]
# # Business Understanding

# %% [markdown]
# We would like to track the COVID-19 Virus spread across the countries and with personal info.
#
# The general information is not so relevant for me.
# I would like to have a deep dive in local development of the spread.

# %% [markdown]
# # Data Understanding

# %% [markdown]
# * Sources of data are:
# * Robert Koch Institute, web scraping : https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Fallzahlen.html
# * Johns Hoppkins University (GITHUB) : https://github.com/CSSEGISandData/COVID-19.git
# * Rest API services to receive data : https://npgeo-corona-npgeo-de.hub.arcgis.com/

# %%
import pandas as pd

# %%
data_path = (r'C:\Users\patka\enterprise_data_science-covid-19\data\raw\csse_covid_19_data\csse_covid_19_time_series\time_series_covid19_confirmed_global.csv')
pd_raw=pd.read_csv(data_path)

pd_raw
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 280            NaN    West Bank and Gaza  31.952200   35.233200        0
# 281            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 282            NaN                 Yemen  15.552727   48.516388        0
# 283            NaN                Zambia -13.133897   27.849332        0
# 284            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/8/22  6/9/22  \
# ...
